# %%
import pandas as pd

# %%
df = pd.read_csv('./Desktop/pydatadc_2018-tidy-master/data/gapminder.tsv', sep='\t')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.shape
# Out:
# (1704, 6)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df[['country','year','lifeExp']]
# Out:
#           country  year  lifeExp
# 0     Afghanistan  1952   28.801
# 1     Afghanistan  1957   30.332
# 2     Afghanistan  1962   31.997
# 3     Afghanistan  1967   34.020
# 4     Afghanistan  1972   36.088
# 5     Afghanistan  1977   38.438
# 6     Afghanistan  1982   39.854
# 7     Afghanistan  1987   40.822
# 8     Afghanistan  1992   41.674
# 9     Afghanistan  1997   41.763
# 10    Afghanistan  2002   42.129
# 11    Afghanistan  2007   43.828
# 12        Albania  1952   55.230
# 13        Albania  1957   59.280
# 14        Albania  1962   64.820
# 15        Albania  1967   66.220
# 16        Albania  1972   67.690
# 17        Albania  1977   68.930
# 18        Albania  1982   70.420
# 19        Albania  1987   72.000
# 20        Albania  1992   71.581
# 21        Albania  1997   72.950
# 22        Albania  2002   75.651
# 23        Albania  2007   76.423
# 24        Algeria  1952   43.077
# 25        Algeria  1957   45.685
# 26        Algeria  1962   48.303
# ...

# %%
df.iloc[1,2]
# Out:
# 1957

# %%
df.loc[(df.country=='India')&(df.year==2007)]
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
pew = pd.read_csv('./Desktop/pydatadc_2018-tidy-master/data/pew.csv')

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
pew.shape
# Out:
# (18, 11)

# %%
 pew_long =pd.melt(pew,id_vars='religion',var_name='income', value_name='count')

# %%
pew_long.head(
)
# Out:
#              religion income  count
# 0            Agnostic  <$10k     27
# 1             Atheist  <$10k     12
# 2            Buddhist  <$10k     27
# 3            Catholic  <$10k    418
# 4  Don’t know/refused  <$10k     15

# %%
bill = pd.read_csv('./Desktop/pydatadc_2018-tidy-master/data/billboard.csv')

# %%
bill.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a0bc17ffbda> in <module>()
# ----> 1 bill.head()
#
# NameError: name 'bill' is not defined

# %%
bill_melt = pd.melt(bill,id_vars=['year','artist','track','time','date.entered'],var_name='week', value_name='rating')
bill_melt
bill_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 7 columns):
# year            24092 non-null int64
# artist          24092 non-null object
# track           24092 non-null object
# time            24092 non-null object
# date.entered    24092 non-null object
# week            24092 non-null object
# rating          5307 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
bill_melt .loc[bill_melt.track=='Loser']
# Out:
#        year        artist  track  time date.entered  week  rating
# 3      2000  3 Doors Down  Loser  4:24   2000-10-21   wk1    76.0
# 320    2000  3 Doors Down  Loser  4:24   2000-10-21   wk2    76.0
# 637    2000  3 Doors Down  Loser  4:24   2000-10-21   wk3    72.0
# 954    2000  3 Doors Down  Loser  4:24   2000-10-21   wk4    69.0
# 1271   2000  3 Doors Down  Loser  4:24   2000-10-21   wk5    67.0
# 1588   2000  3 Doors Down  Loser  4:24   2000-10-21   wk6    65.0
# 1905   2000  3 Doors Down  Loser  4:24   2000-10-21   wk7    55.0
# 2222   2000  3 Doors Down  Loser  4:24   2000-10-21   wk8    59.0
# 2539   2000  3 Doors Down  Loser  4:24   2000-10-21   wk9    62.0
# 2856   2000  3 Doors Down  Loser  4:24   2000-10-21  wk10    61.0
# 3173   2000  3 Doors Down  Loser  4:24   2000-10-21  wk11    61.0
# 3490   2000  3 Doors Down  Loser  4:24   2000-10-21  wk12    59.0
# 3807   2000  3 Doors Down  Loser  4:24   2000-10-21  wk13    61.0
# ...

# %%
bill_songs = bill_melt.loc[:,['year','artist','track','time']]
bill_songs = bill_songs.drop_duplicates()
bill_songs['song_id']= range(len(bill_songs))

new_bill = bill_melt.merge(bill_songs,on=['year','artist','track','time'])
new_bill = new_bill[['year','song_id','week','rating']]
bill_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 5 columns):
# year       317 non-null int64
# artist     317 non-null object
# track      317 non-null object
# time       317 non-null object
# song_id    317 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 14.9+ KB

# %%
new_bill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24092 entries, 0 to 24091
# Data columns (total 4 columns):
# year       24092 non-null int64
# song_id    24092 non-null int64
# week       24092 non-null object
# rating     5307 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 941.1+ KB

# %%
ebola = pd.read_csv('./Desktop/pydatadc_2018-tidy-master/data/country_timeseries.csv')

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola_melt = pd.melt(ebola,id_vars=['Date','Day'], var_name='case', value_name='value')

# %%
ebola_melt.head(250)
# Out:
#            Date  Day               case    value
# 0      1/5/2015  289       Cases_Guinea   2776.0
# 1      1/4/2015  288       Cases_Guinea   2775.0
# 2      1/3/2015  287       Cases_Guinea   2769.0
# 3      1/2/2015  286       Cases_Guinea      NaN
# 4    12/31/2014  284       Cases_Guinea   2730.0
# 5    12/28/2014  281       Cases_Guinea   2706.0
# 6    12/27/2014  280       Cases_Guinea   2695.0
# 7    12/24/2014  277       Cases_Guinea   2630.0
# 8    12/21/2014  273       Cases_Guinea   2597.0
# 9    12/20/2014  272       Cases_Guinea   2571.0
# 10   12/18/2014  271       Cases_Guinea      NaN
# 11   12/14/2014  267       Cases_Guinea   2416.0
# 12    12/9/2014  262       Cases_Guinea      NaN
# 13    12/7/2014  260       Cases_Guinea   2292.0
# 14    12/3/2014  256       Cases_Guinea      NaN
# 15   11/30/2014  253       Cases_Guinea   2164.0
# 16   11/28/2014  251       Cases_Guinea      NaN
# 17   11/23/2014  246       Cases_Guinea   2134.0
# ...

# %%
ebola_melt[['status','country']]=ebola_melt.case.str.split('_', expand=True)
ebola_melt[['status','country']]
# Out:
#       status country
# 0      Cases  Guinea
# 1      Cases  Guinea
# 2      Cases  Guinea
# 3      Cases  Guinea
# 4      Cases  Guinea
# 5      Cases  Guinea
# 6      Cases  Guinea
# 7      Cases  Guinea
# 8      Cases  Guinea
# 9      Cases  Guinea
# 10     Cases  Guinea
# 11     Cases  Guinea
# 12     Cases  Guinea
# 13     Cases  Guinea
# 14     Cases  Guinea
# 15     Cases  Guinea
# 16     Cases  Guinea
# 17     Cases  Guinea
# 18     Cases  Guinea
# 19     Cases  Guinea
# 20     Cases  Guinea
# 21     Cases  Guinea
# 22     Cases  Guinea
# 23     Cases  Guinea
# 24     Cases  Guinea
# 25     Cases  Guinea
# 26     Cases  Guinea
# 27     Cases  Guinea
# 28     Cases  Guinea
# 29     Cases  Guinea
# ...      ...     ...
# 1922  Deaths    Mali
# 1923  Deaths    Mali
# 1924  Deaths    Mali
# 1925  Deaths    Mali
# 1926  Deaths    Mali
# 1927  Deaths    Mali
# 1928  Deaths    Mali
# 1929  Deaths    Mali
# 1930  Deaths    Mali
# 1931  Deaths    Mali
# 1932  Deaths    Mali
# ...

# %%
ebola_melt.drop(columns='case')

ebola_melt = ebola_melt[['Date','Day','country','status','value']]

# %%
ebola_melt
# Out:
#             Date  Day country  status   value
# 0       1/5/2015  289  Guinea   Cases  2776.0
# 1       1/4/2015  288  Guinea   Cases  2775.0
# 2       1/3/2015  287  Guinea   Cases  2769.0
# 3       1/2/2015  286  Guinea   Cases     NaN
# 4     12/31/2014  284  Guinea   Cases  2730.0
# 5     12/28/2014  281  Guinea   Cases  2706.0
# 6     12/27/2014  280  Guinea   Cases  2695.0
# 7     12/24/2014  277  Guinea   Cases  2630.0
# 8     12/21/2014  273  Guinea   Cases  2597.0
# 9     12/20/2014  272  Guinea   Cases  2571.0
# 10    12/18/2014  271  Guinea   Cases     NaN
# 11    12/14/2014  267  Guinea   Cases  2416.0
# 12     12/9/2014  262  Guinea   Cases     NaN
# 13     12/7/2014  260  Guinea   Cases  2292.0
# 14     12/3/2014  256  Guinea   Cases     NaN
# 15    11/30/2014  253  Guinea   Cases  2164.0
# 16    11/28/2014  251  Guinea   Cases     NaN
# 17    11/23/2014  246  Guinea   Cases  2134.0
# 18    11/22/2014  245  Guinea   Cases     NaN
# ...

# %%
weather = pd.read_csv('./Desktop/pydatadc_2018-tidy-master/data/weather.csv')

# %%
weather_melt = pd.melt(weather, id_vars=['id','year','month','element'], var_name='day',value_name='temp')

# %%
weather_pivot = weather_melt.pivot_table(index=['id','year','month','day'],columns='element',values='temp')

# %%
weather_pivot.reset_index()
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1  d30  27.8  14.5
# 1        MX17004  2010      2  d11  29.7  13.4
# 2        MX17004  2010      2   d2  27.3  14.4
# 3        MX17004  2010      2  d23  29.9  10.7
# 4        MX17004  2010      2   d3  24.1  14.4
# 5        MX17004  2010      3  d10  34.5  16.8
# 6        MX17004  2010      3  d16  31.1  17.6
# 7        MX17004  2010      3   d5  32.1  14.2
# 8        MX17004  2010      4  d27  36.3  16.7
# 9        MX17004  2010      5  d27  33.2  18.2
# 10       MX17004  2010      6  d17  28.0  17.5
# 11       MX17004  2010      6  d29  30.1  18.0
# 12       MX17004  2010      7   d3  28.6  17.5
# 13       MX17004  2010      7  d14  29.9  16.5
# 14       MX17004  2010      8  d23  26.4  15.0
# 15       MX17004  2010      8   d5  29.6  15.8
# 16       MX17004  2010      8  d29  28.0  15.3
# 17       MX17004  2010      8  d13  29.8  16.5
# 18       MX17004  2010      8  d25  29.7  15.6
# ...

# %%
police = pd.read_csv('./Desktop/pycon-2018-tutorial-master/police.csv')

# %%
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# 5      2005-03-23     09:45          NaN             M          1982.0
# 6      2005-04-01     17:30          NaN             M          1969.0
# 7      2005-06-06     13:20          NaN             F          1986.0
# 8      2005-07-13     10:15          NaN             M          1970.0
# 9      2005-07-13     15:45          NaN             M          1970.0
# 10     2005-07-13     16:20          NaN             M          1979.0
# 11     2005-07-13     19:00          NaN             F          1966.0
# ...
